# %% [markdown]
# # Pokémon Battle Outcome Analysis
#
# Welcome to this Jupyter Notebook where we delve into the fascinating world of Pokémon battle outcomes. Our goal is to analyze patterns, identify top performers, and understand how different attributes contribute to a Pokémon's success in battles.
#
# ## Purpose of the Notebook
#
# Up to this point, in the pokemon_module.py we have:
#
# - Imported essential libraries and datasets.
# - Conducted preliminary data cleaning and exploration to understand the structure and quality of our data.
# - Created a Pokemon class with attributes and methods for battle.
# - Created a runbattle() function to fight one pokemon against an opponent
#
# ## How to Proceed
#
# **Important:** This notebook is designed for interactive exploration and analysis. To ensure you can tailor the analysis to your specific interests without immediately engaging in computationally expensive processes, certain blocks of code, particularly those involving extensive calculations or data processing, are commented out.

# %%
# Import Statements
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
import requests
from PIL import Image
from io import BytesIO
# set pandas copy on write to be true
pd.set_option("mode.copy_on_write", True)
import pokemon_module as pk
import csv
import copy
import ast
# create a dictionary of pokemon
Pokemon_df_level12 = pd.read_csv('Input_data_files/pokemon.csv', index_col = 'name', keep_default_na=False)
pokemon_dict2 = pk.create_pokemon_dict()
# Out:
# bulbasaur created with 11 hp
# ivysaur created with 12 hp
# venusaur created with 12 hp
# charmander created with 11 hp
# charmeleon created with 12 hp
# charizard created with 12 hp
# squirtle created with 11 hp
# wartortle created with 12 hp
# blastoise created with 12 hp
# caterpie created with 11 hp
# metapod created with 12 hp
# butterfree created with 12 hp
# weedle created with 11 hp
# kakuna created with 11 hp
# beedrill created with 12 hp
# pidgey created with 11 hp
# pidgeotto created with 12 hp
# pidgeot created with 12 hp
# rattata created with 11 hp
# raticate created with 12 hp
# spearow created with 11 hp
# fearow created with 12 hp
# ekans created with 11 hp
# arbok created with 12 hp
# pikachu created with 11 hp
# raichu created with 12 hp
# sandshrew created with 12 hp
# sandslash created with 12 hp
# nidoran-f created with 12 hp
# nidorina created with 12 hp
# nidoqueen created with 12 hp
# nidoran-m created with 11 hp
# nidorino created with 12 hp
# nidoking created with 12 hp
# clefairy created with 12 hp
# clefable created with 12 hp
# vulpix created with 11 hp
# ninetales created with 12 hp
# jigglypuff created with 13 hp
# wigglytuff created with 13 hp
# zubat created with 11 hp
# golbat created with 12 hp
# oddish created with 11 hp
# gloom created with 12 hp
# vileplume created with 12 hp
# paras created with 11 hp
# parasect created with 12 hp
# venonat created with 12 hp
# venomoth created with 12 hp
# diglett created with 11 hp
# dugtrio created with 11 hp
# meowth created with 11 hp
# persian created with 12 hp
# psyduck created with 12 hp
# golduck created with 12 hp
# mankey created with 11 hp
# primeape created with 12 hp
# growlithe created with 12 hp
# arcanine created with 12 hp
# poliwag created with 11 hp
# poliwhirl created with 12 hp
# poliwrath created with 12 hp
# abra created with 11 hp
# kadabra created with 11 hp
# alakazam created with 12 hp
# machop created with 12 hp
# machoke created with 12 hp
# machamp created with 12 hp
# bellsprout created with 12 hp
# weepinbell created with 12 hp
# victreebel created with 12 hp
# tentacool created with 11 hp
# tentacruel created with 12 hp
# geodude created with 11 hp
# graveler created with 12 hp
# golem created with 12 hp
# ponyta created with 12 hp
# rapidash created with 12 hp
# slowpoke created with 12 hp
# slowbro created with 12 hp
# magnemite created with 11 hp
# magneton created with 12 hp
# farfetchd created with 12 hp
# doduo created with 11 hp
# dodrio created with 12 hp
# seel created with 12 hp
# dewgong created with 12 hp
# grimer created with 12 hp
# muk created with 13 hp
# shellder created with 11 hp
# cloyster created with 12 hp
# gastly created with 11 hp
# haunter created with 11 hp
# gengar created with 12 hp
# onix created with 11 hp
# drowzee created with 12 hp
# hypno created with 12 hp
# krabby created with 11 hp
# kingler created with 12 hp
# voltorb created with 11 hp
# electrode created with 12 hp
# exeggcute created with 12 hp
# exeggutor created with 12 hp
# cubone created with 12 hp
# marowak created with 12 hp
# hitmonlee created with 12 hp
# hitmonchan created with 12 hp
# lickitung created with 12 hp
# koffing created with 11 hp
# weezing created with 12 hp
# rhyhorn created with 12 hp
# rhydon created with 13 hp
# chansey created with 16 hp
# tangela created with 12 hp
# kangaskhan created with 13 hp
# horsea created with 11 hp
# seadra created with 12 hp
# goldeen created with 11 hp
# seaking created with 12 hp
# staryu created with 11 hp
# starmie created with 12 hp
# mr-mime created with 11 hp
# scyther created with 12 hp
# jynx created with 12 hp
# electabuzz created with 12 hp
# magmar created with 12 hp
# pinsir created with 12 hp
# tauros created with 12 hp
# magikarp created with 11 hp
# gyarados created with 12 hp
# lapras created with 13 hp
# ditto created with 11 hp
# eevee created with 12 hp
# vaporeon created with 13 hp
# jolteon created with 12 hp
# flareon created with 12 hp
# porygon created with 12 hp
# omanyte created with 11 hp
# omastar created with 12 hp
# kabuto created with 11 hp
# kabutops created with 12 hp
# aerodactyl created with 12 hp
# snorlax created with 14 hp
# articuno created with 12 hp
# zapdos created with 12 hp
# moltres created with 12 hp
# dratini created with 11 hp
# dragonair created with 12 hp
# dragonite created with 12 hp
# mewtwo created with 13 hp
# mew created with 13 hp

# %%
print(f'A level {pokemon_dict2["charmander"].level} {pokemon_dict2["charmander"].name} has {pokemon_dict2["charmander"].hp} hp and {pokemon_dict2["charmander"].attack} attack')
# Out:
# A level 1.0 charmander has 11 hp and 6 attack

# %%
print(f'A level {pokemon_dict2["mew"].level} {pokemon_dict2["mew"].name} has {pokemon_dict2["mew"].hp} hp and {pokemon_dict2["mew"].attack} attack')
# Out:
# A level 1.0 mew has 13 hp and 7 attack

# %%
pokemon_dict2 = pk.create_pokemon_dict(pk_level= 50)
print(f'A level {pokemon_dict2["charmander"].level} {pokemon_dict2["charmander"].name} has {pokemon_dict2["charmander"].hp} hp and {pokemon_dict2["charmander"].attack} attack')
# Out:
# bulbasaur created with 105 hp
# ivysaur created with 120 hp
# venusaur created with 140 hp
# charmander created with 99 hp
# charmeleon created with 118 hp
# charizard created with 138 hp
# squirtle created with 104 hp
# wartortle created with 119 hp
# blastoise created with 139 hp
# caterpie created with 105 hp
# metapod created with 110 hp
# butterfree created with 120 hp
# weedle created with 100 hp
# kakuna created with 105 hp
# beedrill created with 125 hp
# pidgey created with 100 hp
# pidgeotto created with 123 hp
# pidgeot created with 143 hp
# rattata created with 90 hp
# raticate created with 115 hp
# spearow created with 100 hp
# fearow created with 125 hp
# ekans created with 95 hp
# arbok created with 120 hp
# pikachu created with 95 hp
# raichu created with 120 hp
# sandshrew created with 110 hp
# sandslash created with 135 hp
# nidoran-f created with 115 hp
# nidorina created with 130 hp
# nidoqueen created with 150 hp
# nidoran-m created with 106 hp
# nidorino created with 121 hp
# nidoking created with 141 hp
# clefairy created with 130 hp
# clefable created with 155 hp
# vulpix created with 98 hp
# ninetales created with 133 hp
# jigglypuff created with 175 hp
# wigglytuff created with 200 hp
# zubat created with 100 hp
# golbat created with 135 hp
# oddish created with 105 hp
# gloom created with 120 hp
# vileplume created with 135 hp
# paras created with 95 hp
# parasect created with 120 hp
# venonat created with 120 hp
# venomoth created with 130 hp
# diglett created with 70 hp
# dugtrio created with 95 hp
# meowth created with 100 hp
# persian created with 125 hp
# psyduck created with 110 hp
# golduck created with 140 hp
# mankey created with 100 hp
# primeape created with 125 hp
# growlithe created with 115 hp
# arcanine created with 150 hp
# poliwag created with 100 hp
# poliwhirl created with 125 hp
# poliwrath created with 150 hp
# abra created with 85 hp
# kadabra created with 100 hp
# alakazam created with 115 hp
# machop created with 130 hp
# machoke created with 140 hp
# machamp created with 150 hp
# bellsprout created with 110 hp
# weepinbell created with 125 hp
# victreebel created with 140 hp
# tentacool created with 100 hp
# tentacruel created with 140 hp
# geodude created with 100 hp
# graveler created with 115 hp
# golem created with 140 hp
# ponyta created with 110 hp
# rapidash created with 125 hp
# slowpoke created with 150 hp
# slowbro created with 155 hp
# magnemite created with 85 hp
# magneton created with 110 hp
# farfetchd created with 112 hp
# doduo created with 95 hp
# dodrio created with 120 hp
# seel created with 125 hp
# dewgong created with 150 hp
# grimer created with 140 hp
# muk created with 165 hp
# shellder created with 90 hp
# cloyster created with 110 hp
# gastly created with 90 hp
# haunter created with 105 hp
# gengar created with 120 hp
# onix created with 95 hp
# drowzee created with 120 hp
# hypno created with 145 hp
# krabby created with 90 hp
# kingler created with 115 hp
# voltorb created with 100 hp
# electrode created with 120 hp
# exeggcute created with 120 hp
# exeggutor created with 155 hp
# cubone created with 110 hp
# marowak created with 120 hp
# hitmonlee created with 110 hp
# hitmonchan created with 110 hp
# lickitung created with 150 hp
# koffing created with 100 hp
# weezing created with 125 hp
# rhyhorn created with 140 hp
# rhydon created with 165 hp
# chansey created with 310 hp
# tangela created with 125 hp
# kangaskhan created with 165 hp
# horsea created with 90 hp
# seadra created with 115 hp
# goldeen created with 105 hp
# seaking created with 140 hp
# staryu created with 90 hp
# starmie created with 120 hp
# mr-mime created with 100 hp
# scyther created with 130 hp
# jynx created with 125 hp
# electabuzz created with 125 hp
# magmar created with 125 hp
# pinsir created with 125 hp
# tauros created with 135 hp
# magikarp created with 80 hp
# gyarados created with 155 hp
# lapras created with 190 hp
# ditto created with 108 hp
# eevee created with 115 hp
# vaporeon created with 190 hp
# jolteon created with 125 hp
# flareon created with 125 hp
# porygon created with 125 hp
# omanyte created with 95 hp
# omastar created with 130 hp
# kabuto created with 90 hp
# kabutops created with 120 hp
# aerodactyl created with 140 hp
# snorlax created with 220 hp
# articuno created with 150 hp
# zapdos created with 150 hp
# moltres created with 150 hp
# dratini created with 101 hp
# dragonair created with 121 hp
# dragonite created with 151 hp
# mewtwo created with 166 hp
# mew created with 160 hp
# A level 50.0 charmander has 99 hp and 57 attack

# %%
pokemon_dict2 = pk.create_pokemon_dict(Pokemon_df_level12, pk_level= 50)
print(f'A level {pokemon_dict2["mew"].level} {pokemon_dict2["mew"].name} has {pokemon_dict2["mew"].hp} hp and {pokemon_dict2["mew"].attack} attack')
# Out:
# bulbasaur created with 105 hp
# ivysaur created with 120 hp
# venusaur created with 140 hp
# charmander created with 99 hp
# charmeleon created with 118 hp
# charizard created with 138 hp
# squirtle created with 104 hp
# wartortle created with 119 hp
# blastoise created with 139 hp
# caterpie created with 105 hp
# metapod created with 110 hp
# butterfree created with 120 hp
# weedle created with 100 hp
# kakuna created with 105 hp
# beedrill created with 125 hp
# pidgey created with 100 hp
# pidgeotto created with 123 hp
# pidgeot created with 143 hp
# rattata created with 90 hp
# raticate created with 115 hp
# spearow created with 100 hp
# fearow created with 125 hp
# ekans created with 95 hp
# arbok created with 120 hp
# pikachu created with 95 hp
# raichu created with 120 hp
# sandshrew created with 110 hp
# sandslash created with 135 hp
# nidoran-f created with 115 hp
# nidorina created with 130 hp
# nidoqueen created with 150 hp
# nidoran-m created with 106 hp
# nidorino created with 121 hp
# nidoking created with 141 hp
# clefairy created with 130 hp
# clefable created with 155 hp
# vulpix created with 98 hp
# ninetales created with 133 hp
# jigglypuff created with 175 hp
# wigglytuff created with 200 hp
# zubat created with 100 hp
# golbat created with 135 hp
# oddish created with 105 hp
# gloom created with 120 hp
# vileplume created with 135 hp
# paras created with 95 hp
# parasect created with 120 hp
# venonat created with 120 hp
# venomoth created with 130 hp
# diglett created with 70 hp
# dugtrio created with 95 hp
# meowth created with 100 hp
# persian created with 125 hp
# psyduck created with 110 hp
# golduck created with 140 hp
# mankey created with 100 hp
# primeape created with 125 hp
# growlithe created with 115 hp
# arcanine created with 150 hp
# poliwag created with 100 hp
# poliwhirl created with 125 hp
# poliwrath created with 150 hp
# abra created with 85 hp
# kadabra created with 100 hp
# alakazam created with 115 hp
# machop created with 130 hp
# machoke created with 140 hp
# machamp created with 150 hp
# bellsprout created with 110 hp
# weepinbell created with 125 hp
# victreebel created with 140 hp
# tentacool created with 100 hp
# tentacruel created with 140 hp
# geodude created with 100 hp
# graveler created with 115 hp
# golem created with 140 hp
# ponyta created with 110 hp
# rapidash created with 125 hp
# slowpoke created with 150 hp
# slowbro created with 155 hp
# magnemite created with 85 hp
# magneton created with 110 hp
# farfetchd created with 112 hp
# doduo created with 95 hp
# dodrio created with 120 hp
# seel created with 125 hp
# dewgong created with 150 hp
# grimer created with 140 hp
# muk created with 165 hp
# shellder created with 90 hp
# cloyster created with 110 hp
# gastly created with 90 hp
# haunter created with 105 hp
# gengar created with 120 hp
# onix created with 95 hp
# drowzee created with 120 hp
# hypno created with 145 hp
# krabby created with 90 hp
# kingler created with 115 hp
# voltorb created with 100 hp
# electrode created with 120 hp
# exeggcute created with 120 hp
# exeggutor created with 155 hp
# cubone created with 110 hp
# marowak created with 120 hp
# hitmonlee created with 110 hp
# hitmonchan created with 110 hp
# lickitung created with 150 hp
# koffing created with 100 hp
# weezing created with 125 hp
# rhyhorn created with 140 hp
# rhydon created with 165 hp
# chansey created with 310 hp
# tangela created with 125 hp
# kangaskhan created with 165 hp
# horsea created with 90 hp
# seadra created with 115 hp
# goldeen created with 105 hp
# seaking created with 140 hp
# staryu created with 90 hp
# starmie created with 120 hp
# mr-mime created with 100 hp
# scyther created with 130 hp
# jynx created with 125 hp
# electabuzz created with 125 hp
# magmar created with 125 hp
# pinsir created with 125 hp
# tauros created with 135 hp
# magikarp created with 80 hp
# gyarados created with 155 hp
# lapras created with 190 hp
# ditto created with 108 hp
# eevee created with 115 hp
# vaporeon created with 190 hp
# jolteon created with 125 hp
# flareon created with 125 hp
# porygon created with 125 hp
# omanyte created with 95 hp
# omastar created with 130 hp
# kabuto created with 90 hp
# kabutops created with 120 hp
# aerodactyl created with 140 hp
# snorlax created with 220 hp
# articuno created with 150 hp
# zapdos created with 150 hp
# moltres created with 150 hp
# dratini created with 101 hp
# dragonair created with 121 hp
# dragonite created with 151 hp
# mewtwo created with 166 hp
# mew created with 160 hp
# A level 50.0 mew has 160 hp and 105 attack

# %%
Pokemon_df2 = pk.levelup(Pokemon_df_level12, level=50)
Pokemon_df2
# Out:
#             pokedex_number  generation    type1   type2  height_(m)  \
# name
# bulbasaur                1           1    grass  poison         0.7
# ivysaur                  2           1    grass  poison         1.0
# venusaur                 3           1    grass  poison         2.0
# charmander               4           1     fire     N/A         0.6
# charmeleon               5           1     fire     N/A         1.1
# ...                    ...         ...      ...     ...         ...
# dratini                147           1   dragon     N/A         1.8
# dragonair              148           1   dragon     N/A         4.0
# dragonite              149           1   dragon  flying         2.2
# mewtwo                 150           1  psychic     N/A         2.0
# mew                    151           1  psychic     N/A         0.4
#
#             weight_(kg)  base_total   hp  attack  defense  ...  against_grass  \
# name                                                       ...
# bulbasaur           6.9         403  105      54       54  ...            1.0
# ivysaur            13.0         490  120      67       68  ...            1.0
# venusaur          100.0         610  140      87       88  ...            1.0
# charmander          8.5         394   99      57       48  ...            2.0
# charmeleon         19.0         490  118      69       63  ...            2.0
# ...                 ...         ...  ...     ...      ...  ...            ...
# dratini             3.3         385  101      69       50  ...            1.0
# dragonair          16.5         505  121      89       70  ...            1.0
# dragonite         210.0         685  151     139      100  ...            2.0
# mewtwo            122.0         765  166     115       95  ...            1.0
# mew                 4.0         685  160     105      105  ...            1.0
#
#             against_ground  against_ice against_normal  against_poison  \
# name
# bulbasaur              1.0          1.0            1.0            0.25
# ivysaur                1.0          1.0            1.0            0.25
# venusaur               1.0          1.0            1.0            0.25
# charmander             1.0          2.0            1.0            1.00
# charmeleon             1.0          2.0            1.0            1.00
# ...                    ...          ...            ...             ...
# dratini                1.0          1.0            1.0            1.00
# dragonair              1.0          1.0            1.0            1.00
# dragonite              1.0          1.0            1.0            1.00
# mewtwo                 1.0          1.0            1.0            2.00
# mew                    1.0          1.0            1.0            2.00
#
#             against_psychic  against_rock  against_steel  against_water  level
# name
# bulbasaur               1.0           1.0           0.50            2.0   50.0
# ivysaur                 1.0           1.0           0.50            2.0   50.0
# venusaur                1.0           1.0           0.50            2.0   50.0
# charmander              1.0           0.5           2.00            0.5   50.0
# charmeleon              1.0           0.5           2.00            0.5   50.0
# ...                     ...           ...            ...            ...    ...
# dratini                 1.0           1.0           0.50            1.0   50.0
# dragonair               1.0           1.0           0.50            1.0   50.0
# dragonite               1.0           0.5           0.25            1.0   50.0
# mewtwo                  0.5           1.0           0.50            1.0   50.0
# mew                     0.5           1.0           0.50            1.0   50.0
#
# [151 rows x 33 columns]

# %%
Pokemon_df_level12
# Out:
#             pokedex_number  generation    type1   type2  height_(m)  \
# name
# bulbasaur                1           1    grass  poison         0.7
# ivysaur                  2           1    grass  poison         1.0
# venusaur                 3           1    grass  poison         2.0
# charmander               4           1     fire     N/A         0.6
# charmeleon               5           1     fire     N/A         1.1
# ...                    ...         ...      ...     ...         ...
# dratini                147           1   dragon     N/A         1.8
# dragonair              148           1   dragon     N/A         4.0
# dragonite              149           1   dragon  flying         2.2
# mewtwo                 150           1  psychic     N/A         2.0
# mew                    151           1  psychic     N/A         0.4
#
#             weight_(kg)  base_total   hp  attack  defense  ...  against_ghost  \
# name                                                       ...
# bulbasaur           6.9         318   45      49       49  ...            0.5
# ivysaur            13.0         405   60      62       63  ...            0.5
# venusaur          100.0         525   80      82       83  ...            0.5
# charmander          8.5         309   39      52       43  ...            1.0
# charmeleon         19.0         405   58      64       58  ...            1.0
# ...                 ...         ...  ...     ...      ...  ...            ...
# dratini             3.3         300   41      64       45  ...            1.0
# dragonair          16.5         420   61      84       65  ...            1.0
# dragonite         210.0         600   91     134       95  ...            1.0
# mewtwo            122.0         680  106     110       90  ...            1.0
# mew                 4.0         600  100     100      100  ...            1.0
#
#             against_grass  against_ground against_ice  against_normal  \
# name
# bulbasaur             1.0             1.0         1.0             1.0
# ivysaur               1.0             1.0         1.0             1.0
# venusaur              1.0             1.0         1.0             1.0
# charmander            2.0             1.0         2.0             1.0
# charmeleon            2.0             1.0         2.0             1.0
# ...                   ...             ...         ...             ...
# dratini               1.0             1.0         1.0             1.0
# dragonair             1.0             1.0         1.0             1.0
# dragonite             2.0             1.0         1.0             1.0
# mewtwo                1.0             1.0         1.0             1.0
# mew                   1.0             1.0         1.0             1.0
#
#             against_poison  against_psychic  against_rock  against_steel  \
# name
# bulbasaur             0.25              1.0           1.0           0.50
# ivysaur               0.25              1.0           1.0           0.50
# venusaur              0.25              1.0           1.0           0.50
# charmander            1.00              1.0           0.5           2.00
# charmeleon            1.00              1.0           0.5           2.00
# ...                    ...              ...           ...            ...
# dratini               1.00              1.0           1.0           0.50
# dragonair             1.00              1.0           1.0           0.50
# dragonite             1.00              1.0           0.5           0.25
# mewtwo                2.00              0.5           1.0           0.50
# mew                   2.00              0.5           1.0           0.50
#
#             against_water
# name
# bulbasaur             2.0
# ivysaur               2.0
# venusaur              2.0
# charmander            0.5
# charmeleon            0.5
# ...                   ...
# dratini               1.0
# dragonair             1.0
# dragonite             1.0
# mewtwo                1.0
# mew                   1.0
#
# [151 rows x 32 columns]

# %%
#pk.merged_moves_df.iloc[np.where(pk.merged_moves_df['move'] == 'thunder wave')]

# %%
# uncomment below and pick two pokemon to see a battle
pk.runbattle(pokemon_dict['mew'],pokemon_dict['mewtwo'],verbose=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # uncomment below and pick two pokemon to see a battle
# ----> 2 pk.runbattle(pokemon_dict['mew'],pokemon_dict['mewtwo'],verbose=True)
#
# NameError: name 'pokemon_dict' is not defined

# %%
team_1 = pk.create_pokemon_objects(['articuno','zapdos','moltres','mewtwo','mew','gyarados'])
team_2 = pk.create_pokemon_objects(['gengar','gyarados','articuno','haunter','zapdos','mewtwo'])

winner, winnerlist, rounds= pk.battle_team(team_1,team_2)
print(winner)
print(winnerlist)
print(rounds)
# Out:
# 1st team
# ['articuno', 'gyarados', 'zapdos', 'articuno', 'articuno', 'articuno', 'mew', 'haunter', 'gyarados', 'zapdos']
# 73

# %%
elite4_1 = ['dewgong','cloyster','slowbro','jynx','lapras']
elite4_2 = ['onix','hitmonlee','hitmonchan','onix','machamp']
elite4_3 = ['gengar','golbat','haunter','arbok','gengar']
elite4_4 = ['gyarados','dragonair','dragonair','aerodactyl','dragonite']
elite_list = [elite4_1,elite4_2,elite4_3,elite4_4]

elite = []
for team in elite_list:
    elite.append(pk.create_pokemon_objects(team))

# %%
#Ordered most wins to least wins
team1 = ['gyarados','gyarados','gyarados','gyarados','gyarados','gyarados']
team2 = ['gengar','gengar','gengar','gengar','gengar','gengar']
team3 = ['articuno','zapdos','mewtwo','blastoise','mew','moltres']
team4 = ['gengar','poliwrath','magneton','dragonite','charizard','alakazam']
team5 = ['poliwrath','hitmonchan','machamp','machamp','primeape','hitmonlee']
team6 = ['mewtwo','snorlax','muk','vaporeon','wigglytuff','chansey']
team7 = ['gengar','gyarados','articuno','haunter','zapdos','mewtwo']
team8 = ['gengar','articuno','mewtwo','exeggutor','clefable','vaporeon']
team9 = ['articuno','zapdos','moltres',"dodrio","farfetch'd",'pidgeot']
team10 = ['gengar','lapras','rhydon','venusaur','onix','growlithe']
#ordered in vague type-matching attempt
team7b = ['exeggutor','gengar','vaporeon','clefable','mewtwo','articuno']
teamslist = [team1,team2,team3,team4,team5,team6,team7,team8,team9,team10,team7b]
teams = []
for team in teamslist:
    teams.append(pk.create_pokemon_objects(team))

# %%
teamsreverse = teamslist.copy()
for i in range(len(teamslist)):
    teamsreverse[i].reverse()
# teamsreverse

# %%
teamsbackward = []
for team in teamsreverse:
    teamsbackward.append(pk.create_pokemon_objects(team))

# %%
team1 = ['bulbasaur','charmander','squirtle','pikachu','jigglypuff','meowth']
team1 = pk.create_pokemon_objects(team1)
result,time,teamname,winnerlist = pk.run_elite(team1,elite,verbose=False)
print(result)
print("%.2f minutes" % time)
print(teamname)
print(winnerlist)
# Out:
# 0
# 8.60 minutes
# Lorelei
# ['dewgong', 'dewgong', 'dewgong', 'pikachu', 'cloyster', 'cloyster', 'meowth', 'slowbro']

# %%
bulkyteam = ['gyarados','zapdos','moltres','articuno','mew','mewtwo']
bulkyteam = pk.create_pokemon_objects(bulkyteam)
result,time,teamname,winnerlist = pk.run_elite(bulkyteam,elite,verbose=False,roundreset=False)
print(result)
print("%.2f minutes" % time)
print(teamname)
print(winnerlist)
# Out:
# 1
# 17.30 minutes
# Champion
# ['gyarados2', 'zapdos', 'zapdos', 'zapdos', 'aerodactyl', 'draw', 'articuno']

# %%
def sim_elite(team,elite,num_runs=10):
    results = pd.DataFrame(columns=['Result','Time','Winner','Winner List'])
    for i in range(num_runs):
        result,time,teamname,winnerlist = pk.run_elite(team,elite,verbose=False,roundreset=False)
        results.loc[i] = [result,time,teamname,winnerlist]
    return results

myteam = teams[0]
num_runs = 1000

# results1 = sim_elite(myteam,elite,num_runs=num_runs)
# results1.head()
# results['Result'].value_counts()

# %%
# Function to randomly select a pokemon
def random_pokemon():
    pokemon = np.random.choice(list(pokemon_dict.keys()))
    return pokemon_dict[pokemon]

# function to generate a random team of pokemon
def random_team(n):
    team = []
    for i in range(n):
        team.append(random_pokemon())
    return team

team = random_team(6)
for pokemon in team:
    print(pokemon.name)
# Out:
# cloyster
# seaking
# mewtwo
# zapdos
# arcanine
# wartortle

# %%
# simulate a battle between a random team and the elite four
num_teams = 10
num_runs = 10
for i in range(num_teams):
    team = random_team(6)
    results = sim_elite(team,elite,num_runs=num_runs)
    # print("Team %d" % (i+1))
    # print(results['Result'].value_counts())
results.head()
# Out:
#    Result  Time   Winner                                        Winner List
# 0       0  20.1    Bruno  [koffing, hitmonlee, hitmonlee, tangela, hitmo...
# 1       0  21.5  Lorelei  [dewgong, draw, dewgong, arcanine, tangela, ta...
# 2       0  19.5  Lorelei  [dewgong, snorlax, snorlax, snorlax, snorlax, ...
# 3       0   9.8  Lorelei  [dewgong, snorlax, cloyster, tangela, slowbro,...
# 4       0  32.9   Agatha  [gengar, gengar, gengar, draw, gengar, gengar,...

# %%
num_teams = 120000
num_runs = 100
results = pd.DataFrame()
#  Uncomment to crash your computer


# for i in range(num_teams):
#     team = random_team(6)
#     team_results = sim_elite(team,elite,num_runs=num_runs)
#     teamname = [pokemon.name for pokemon in team]  
#     team_results['Team'] = str(teamname) 
#     results = pd.concat([results,team_results])

# %%
# write results to a csv file
# results.to_csv('Random_Team_results.csv')

# %%
# random_team_results_df = pd.read_csv('Random_Team_results.csv', index_col=0)
# len(random_team_results_df)

# %%
# change index to Team
# random_team_results_df.set_index('Team', inplace=True)
# rename Unnamed: 1 to run
# random_team_results_df.rename(columns={'Run':'Battle Number'}, inplace=True)
# random_team_results_df.rename(columns={'Unnamed: 1':'Run'}, inplace=True)

# %%
# random_team_results_df.tail()

# %%
# loop through different teams in Team
# random_team_total_results2 = pd.DataFrame()
# count = 0
# for team in random_team_results_df.index.unique():
#     count += 1
#     nemesis_dict = {}
#     team_results = random_team_results_df.loc[team]
#     wins = team_results['Result'].value_counts().get(1,0)
#     # calculate average time if win = 1
#     avg_time_win = round(team_results[team_results['Result'] == 1]['Time'].mean(),2)
#     sd_time_win = round(team_results[team_results['Result'] == 1]['Time'].std(),2)
#     # calculate average time if win = 0
#     avg_time_loss = round(team_results[team_results['Result'] == 0]['Time'].mean(),2)
#     sd_time_loss = round(team_results[team_results['Result'] == 0]['Time'].std(),2)
#     # record distribution of winners
#     winner_dict = team_results['Winner'].value_counts().to_dict()
#     # record distribution of nemesis
#     for run in team_results.Run:
#         # convert from string to list
#         nem = ast.literal_eval(team_results.iloc[np.where(team_results.Run == run)]['Winner List'].values[0])
#         nemesis = nem[-1]
#         if nemesis in nemesis_dict:
#             nemesis_dict[nemesis] += 1
#         else:
#             nemesis_dict[nemesis] = 1
#     # update dataframe
#     random_team_total_results2 = pd.concat([random_team_total_results2,pd.DataFrame({'Team':team,'Wins':wins,'Avg Time Win':avg_time_win,'SD Time Win':sd_time_win,
#                                                                                    'Avg Time Loss':avg_time_loss,'SD Time Loss':sd_time_loss,
#                                                                                    'Losses to Lorelei':winner_dict.get('Lorelei',0), 'Losses to Bruno':winner_dict.get('Bruno',0),
#                                                                                    'Losses to Agatha':winner_dict.get('Agatha',0), 'Losses to Lance':winner_dict.get('Lance',0),
#                                                                                    'Nemesis':max(nemesis_dict, key=nemesis_dict.get), 'Nemesis Losses':nemesis_dict[max(nemesis_dict, key=nemesis_dict.get)]},index=[0])])
    
#     print(count)

# %%
num_runs = 1000
# results1 = sim_elite(teams[0],elite,num_runs=num_runs)
# results2 = sim_elite(teams[1],elite,num_runs=num_runs)
# results3 = sim_elite(teams[2],elite,num_runs=num_runs)
# results4 = sim_elite(teams[3],elite,num_runs=num_runs)
# results5 = sim_elite(teams[4],elite,num_runs=num_runs)
# results6 = sim_elite(teams[5],elite,num_runs=num_runs)
# results7 = sim_elite(teams[6],elite,num_runs=num_runs)
# results8 = sim_elite(teams[7],elite,num_runs=num_runs)
# results9 = sim_elite(teams[8],elite,num_runs=num_runs)
# results10 = sim_elite(teams[9],elite,num_runs=num_runs)
# results7b = sim_elite(teams[10],elite,num_runs=num_runs)
# results1b = sim_elite(teamsbackward[0],elite,num_runs=num_runs)
# results2b = sim_elite(teamsbackward[1],elite,num_runs=num_runs)
# results3b = sim_elite(teamsbackward[2],elite,num_runs=num_runs)
# results4b = sim_elite(teamsbackward[3],elite,num_runs=num_runs)
# results5b = sim_elite(teamsbackward[4],elite,num_runs=num_runs)
# results6b = sim_elite(teamsbackward[5],elite,num_runs=num_runs)
# results7b = sim_elite(teamsbackward[6],elite,num_runs=num_runs)
# results8b = sim_elite(teamsbackward[7],elite,num_runs=num_runs)
# results9b = sim_elite(teamsbackward[8],elite,num_runs=num_runs)
# results10b = sim_elite(teamsbackward[9],elite,num_runs=num_runs)
# results7bb = sim_elite(teamsbackward[10],elite,num_runs=num_runs)

# %%
# # create data frame on who you lose to the most
# lose_to = pd.DataFrame(columns=['Winner','Top Pokemon'])
# for row in results1.iterrows():
#     if row[1]['Result'] == 0:
#         lose_to.loc[len(lose_to)] = row[1]['Winner'], row[1]['Winner List'][-1]

# # count who you lose to the most
# lose_to['Winner'].value_counts()

# # count which pokemon you lose to the most
# lose_to['Top Pokemon'].value_counts()

# %%
# function to write multiple results to excel
def write_results(results, sheet_names, file_name):
    with pd.ExcelWriter(file_name) as writer:
        for i in range(len(results)):
            results[i].to_excel(writer, sheet_name=sheet_names[i])
    
# Make sure to pass sheet_names as a list
# write_results([results1,results2,results3,results4,results5,results6,results7,results8,results9,results10,results7b,results1b,results2b,results3b,results4b,results5b,results6b,results7b,results8b,results9b,results10b,results7bb],['team1','team2','team3','team4','team5','team6','team7','team8','team9','team10','team7b','team1b','team2b','team3b','team4b','team5b','team6b','team7b','team8b','team9b','team10b','team7bb'],'elite_results.xlsx')

# %%
# read in the results from the excel file
team_battles = pd.read_excel('Output_data_files/elite_results.xlsx',sheet_name=None, index_col=0)
team_battles.keys()
# Out:
# dict_keys(['team1', 'team2', 'team3', 'team4', 'team5', 'team6', 'team7', 'team8', 'team9', 'team10', 'team11', 'team1b', 'team2b', 'team3b', 'team4b', 'team5b', 'team6b', 'team7b', 'team8b', 'team9b', 'team10b', 'team11b'])

# %%
def get_total_wins_and_times(team_results):
    total_wins = team_results['Result'].sum()
    times = team_results.loc[team_results['Result'] == 1, 'Time'].tolist()
    enemy_dict = dict(team_results.loc[team_results['Result'] == 0, 'Winner'].value_counts())
    return [total_wins, times, enemy_dict]

# total_wins, times, enemy = get_total_wins_and_times(team_battles['team1'])

# %%
# get the total wins and times for all teams
total_wins = []
avg_times = []
enemy_dict = []
for team in team_battles.keys():
    wins, times, enemy = get_total_wins_and_times(team_battles[team])
    total_wins.append(wins)
    avg_time = np.mean(times)
    avg_times.append(avg_time)
    enemy_dict.append(enemy)

# total_wins
avg_times
# Out:
# [[24.4,
#   22.6,
#   25.2,
#   23.6,
#   25.2,
#   21.7,
#   27.7,
#   24.7,
#   19.4,
#   22.7,
#   28.6,
#   22.8,
#   22.6,
#   24.1,
#   29.1,
#   22.5,
#   24.0,
#   26.1,
#   28.4,
#   26.5,
#   26.9,
#   26.6,
#   21.6,
#   24.6,
#   22.1,
#   23.8,
#   22.2,
#   20.4,
#   21.9,
#   23.0,
#   24.3,
#   25.3,
#   23.6,
#   17.4,
#   22.5,
#   31.6,
#   19.3,
#   26.0,
#   23.8,
#   25.4,
#   23.8,
#   22.4,
#   23.4,
#   23.2,
#   22.8,
#   21.9,
#   24.3,
#   24.9,
#   20.5,
#   20.7,
#   23.5,
#   29.2,
#   24.5,
#   26.0,
#   28.5,
#   19.7,
#   25.5,
#   21.6,
#   24.3,
#   23.8,
#   28.3,
#   28.0,
#   22.6,
#   24.4,
#   22.9,
#   24.7,
#   20.0,
#   22.2,
#   27.0,
#   18.7,
#   18.3,
#   28.6,
#   33.9,
#   22.3,
#   25.8,
#   24.6,
#   23.4,
#   26.0,
#   24.2,
#   22.4,
#   23.3,
#   16.4,
# ...
#   34.7,
#   39.1,
#   39.6,
#   35.0,
#   37.9,
#   33.9,
#   35.4,
#   35.6,
#   33.5,
#   37.0,
#   38.3,
#   33.0,
#   29.4,
#   33.3,
#   31.5,
#   30.8,
#   35.4,
#   31.7,
#   38.1,
#   37.6,
#   37.9,
#   32.4,
#   31.6,
#   36.1,
#   41.2,
#   25.5,
#   30.5,
#   31.2,
#   31.5,
#   32.0,
#   44.5,
#   31.5,
#   34.7,
#   35.5,
#   40.7,
#   38.4,
#   32.3,
#   36.6,
#   35.4,
#   33.7,
#   36.8,
#   34.9,
#   25.1,
#   33.1,
#   34.6,
#   35.8,
#   39.0,
#   37.7,
#   34.4,
#   39.7,
#   35.9,
#   38.2,
#   33.0,
#   35.4,
#   29.9,
#   35.3,
#   35.0,
#   30.8,
#   36.7,
#   38.9,
#   40.5,
#   38.7,
#   34.5,
#   34.9,
#   30.0,
#   31.8,
#   33.9,
#   34.1,
#   33.2,
#   29.6,
#   33.6,
#   29.4,
#   32.4,
#   35.7,
#   32.8,
#   30.6,
#   40.1,
#   29.8,
#   34.7,
#   32.7,
#   35.3,
#   26.5,
#   39.8,
#   29.6,
#   32.3,
#   31.3,
#   35.5,
#   23.6,
#   31.8,
#   34.8,
#   30.9,
#   33.1,
#   31.0,
#   35.8,
#   26.7,
#   33.9,
#   41.0,
#   34.0,
#   38.5,
#   38.6,
#   28.8,
#   31.5,
#   29.4,
#   34.5,
#   43.6,
#   29.7,
#   33.6,
#   33.9,
#   33.3,
#   30.7,
#   37.1,
#   26.8,
#   34.9,
#   25.8,
#   38.4,
#   38.4,
#   33.8,
#   37.3,
#   33.7,
#   28.7,
#   42.7,
#   33.2,
#   42.1,
#   38.5,
#   40.2,
#   43.6,
#   50.7,
#   34.3,
#   41.6,
#   32.2,
#   25.7,
#   36.1,
#   39.4,
#   36.9,
#   33.1,
#   35.9,
#   36.4,
#   38.4,
#   35.4,
#   35.4,
#   44.9,
#   38.4,
#   34.6,
#   32.3,
#   37.2,
#   32.4,
#   32.2,
#   30.6,
#   33.5,
#   26.5,
#   37.9,
#   35.2,
#   31.9,
#   40.5,
#   30.2,
#   29.6,
#   41.6,
#   35.3,
#   37.5,
#   34.4,
#   44.3,
#   33.5,
#   25.9,
#   33.1,
#   33.8,
#   32.8,
#   35.8,
#   31.9,
#   37.5,
#   30.3,
#   35.8,
#   40.5,
#   24.8,
#   37.3,
#   32.1,
#   35.1,
#   32.7,
#   36.4,
#   26.1,
#   35.5,
#   37.1,
#   30.1,
#   38.2,
#   31.3,
#   34.8,
#   34.4,
#   34.7,
#   26.8,
#   37.0,
#   30.8,
#   37.4,
#   34.3,
#   35.4,
#   36.0,
#   37.5,
#   34.5,
#   37.8,
#   29.9,
#   36.8,
#   29.7,
#   33.2,
#   30.9,
#   34.5,
#   42.3,
#   32.3,
#   32.7,
#   37.3,
#   36.7,
#   31.5,
#   33.4,
#   30.7,
#   42.2,
#   31.2,
#   35.4,
#   29.4,
#   30.7,
#   29.1,
#   32.4,
#   40.5,
#   36.7,
#   41.7,
#   31.4,
#   35.8,
#   38.8,
#   30.8,
#   22.1,
#   38.5,
#   29.8,
#   42.7,
#   33.7,
#   35.8,
#   36.8,
#   32.0,
#   29.9,
#   37.3,
#   41.5,
#   31.3,
#   36.5,
#   40.2,
#   30.5,
#   32.6,
#   28.5,
#   33.9,
#   33.8,
#   34.1,
#   36.5,
#   35.0,
#   36.1,
#   29.0,
#   39.2,
#   32.5,
#   34.5,
#   39.3,
#   42.5,
#   34.1,
#   37.8,
#   35.8],
#  [],
#  [76.0, 88.4, 75.5, 67.9],
#  [50.7,
#   44.3,
#   41.5,
#   37.7,
#   49.8,
#   47.0,
#   44.1,
#   47.8,
#   44.9,
#   38.8,
#   41.7,
#   40.7,
#   57.6,
#   47.3,
#   53.0,
#   45.1,
#   37.9,
#   57.6,
#   33.9,
#   49.5,
#   42.6,
#   52.0,
#   53.1,
#   63.6,
#   50.6,
#   46.9,
#   38.9,
#   50.7,
#   49.3,
#   49.6,
#   50.1,
#   57.9,
#   49.7,
#   55.5,
#   62.1,
#   52.6,
#   43.6,
#   46.6,
#   61.6,
#   69.1,
#   65.3,
#   49.9,
#   37.3,
#   31.6,
#   57.3,
#   50.2,
#   46.5,
#   49.2,
#   52.7,
#   52.6,
#   40.6,
#   45.8,
#   40.2,
#   45.8,
#   42.0,
#   48.6,
#   46.0,
#   32.6,
#   47.8,
#   58.3,
#   33.6,
#   44.2,
#   57.5,
#   42.3,
#   54.5,
#   47.7,
#   37.5,
#   51.5,
#   42.5,
#   49.5,
#   56.7,
#   39.0,
#   44.3,
#   40.6,
#   51.1,
#   43.7,
#   45.4,
#   36.7,
#   50.6,
#   35.0,
#   34.1,
#   38.6,
#   43.1,
#   52.0,
#   49.1,
#   51.4,
#   51.1,
#   47.9,
#   36.9,
#   46.1,
#   52.9,
#   42.4,
#   46.4,
#   55.7,
#   40.0,
#   60.2,
#   43.5,
#   53.3,
#   42.6,
#   55.7,
#   44.1,
#   52.6,
#   49.3,
#   35.9,
#   67.3,
#   52.2,
#   57.5,
#   43.9,
#   58.1,
#   43.2,
#   43.0,
#   40.3,
#   55.1,
#   47.2,
#   48.9,
#   43.4,
#   50.0,
#   42.8,
#   51.3,
#   46.3,
#   49.5,
#   64.8,
#   42.1,
#   46.0,
#   52.7,
#   38.9,
#   55.5,
#   39.3,
#   41.5,
#   33.8,
#   53.1,
#   54.8,
#   44.6,
#   53.6,
#   48.7,
#   47.0,
#   47.5,
#   34.4,
#   35.4,
#   44.1,
#   43.8,
#   52.3,
#   51.4,
#   51.8,
#   36.3,
#   40.1,
#   46.0,
#   42.4,
#   42.7,
#   44.5,
#   50.3,
#   46.5,
#   40.9,
#   44.2,
#   47.3,
#   45.9,
#   41.4,
#   52.2,
#   53.1,
#   55.4,
#   40.7,
#   47.8,
#   56.2,
#   37.4,
#   51.2,
#   53.0,
#   58.5,
#   45.5,
#   47.0,
#   42.3,
#   40.0,
#   64.4,
#   51.4,
#   33.3,
#   51.7,
#   48.1,
#   41.6,
#   56.6,
#   51.8,
#   58.5,
#   41.5,
#   46.5,
#   56.4,
#   44.1,
#   41.7,
#   43.1,
#   40.5,
#   38.7,
#   56.8,
#   42.1,
#   45.6,
#   50.2,
#   50.4,
#   57.0,
#   32.5,
#   56.0,
#   38.3,
#   58.9,
#   38.8,
#   38.2,
#   38.7,
#   51.8,
#   47.0,
#   38.5,
#   49.0,
#   45.2,
#   45.6,
#   48.8,
#   39.1,
#   47.6,
#   34.0,
#   57.1,
#   54.3,
#   54.7,
#   43.3,
#   50.5,
#   52.1,
#   44.7,
#   60.4,
#   54.6,
#   51.8,
#   55.6,
#   41.2,
#   46.7,
#   36.9,
#   39.0,
#   44.3,
#   50.5,
#   45.0,
#   51.0,
#   50.5,
#   53.0,
#   54.3,
#   56.7,
#   58.8,
#   54.7,
#   39.5,
#   44.5,
#   52.5,
#   49.9,
#   43.7,
#   38.3,
#   46.0,
#   38.3,
#   39.1,
#   42.7,
#   45.6,
#   40.6,
#   48.1,
#   42.5,
#   45.2,
#   40.3,
#   47.8,
#   47.2,
#   50.3,
#   47.7,
#   54.0,
#   46.2,
#   44.9,
#   48.4,
#   68.8,
#   56.0,
#   54.9,
#   50.4,
#   56.9,
#   45.9,
#   56.5,
#   52.9,
#   54.1,
#   41.8,
#   46.6,
#   55.2,
#   38.3,
#   49.1,
#   38.8,
#   49.5,
#   42.8,
#   44.1,
#   57.9,
#   47.0,
#   42.0,
#   55.6,
#   50.6,
#   42.3,
#   42.7,
#   52.7,
#   40.5,
#   55.6,
#   41.4,
#   36.0,
#   45.1,
#   48.3,
#   52.0,
#   50.6,
#   49.2,
#   42.3,
#   48.4,
#   46.4,
#   58.1,
#   44.7,
#   52.6,
#   47.3,
#   50.2,
#   49.7,
#   57.9,
#   49.5,
#   53.2,
#   50.7,
#   40.5,
#   34.3,
#   52.8,
#   50.0,
#   43.8,
#   57.8,
#   57.1,
#   47.2,
#   40.4,
#   51.7,
#   46.8,
#   51.4,
#   46.0,
#   52.9,
#   46.4,
#   48.2,
#   48.3,
#   50.4,
#   47.9,
#   43.0,
#   34.5,
#   50.3,
#   52.6,
#   45.9,
#   42.3,
#   52.6,
#   46.2,
#   42.8,
#   42.6,
#   41.5,
#   55.6,
#   41.6,
#   46.2,
#   42.3,
#   54.4,
#   56.3,
#   41.1,
#   51.9,
#   51.1,
#   51.7,
#   51.0,
#   49.7,
#   40.1,
#   46.0,
#   41.6,
#   45.1,
#   43.4,
#   47.7,
#   44.6,
#   36.0,
#   58.0,
#   50.1,
#   40.6,
#   51.9,
#   59.0,
#   50.2,
#   42.1,
#   60.0,
#   55.3,
#   46.8,
#   45.1,
#   49.6,
#   48.4,
#   45.4,
#   64.8,
#   49.1,
#   51.5,
#   54.7,
#   44.9,
#   52.4,
#   40.3,
#   43.4,
#   46.7,
#   47.8,
#   57.3,
#   50.9,
#   46.2,
#   45.3,
#   43.2,
#   38.7,
#   50.6,
#   62.5,
#   47.4,
#   51.2,
#   33.1,
#   42.2,
#   44.5,
#   49.9,
#   53.2,
#   37.9,
#   59.3,
#   40.6,
#   54.6,
#   42.3,
#   60.7,
#   42.9,
#   46.1,
#   46.9,
#   50.7,
#   55.8,
#   52.1,
#   44.2,
#   62.8,
#   41.3,
#   42.2,
#   37.4,
#   51.5,
#   45.8,
#   49.3,
#   51.0,
#   63.4,
#   42.7,
#   49.3,
#   44.9,
#   42.5,
#   54.0,
#   51.5,
#   41.7,
#   62.0,
#   42.8,
#   43.7,
#   44.3,
#   57.5,
#   47.1,
#   49.8,
#   50.1,
#   50.2,
#   35.1,
#   35.4,
#   45.9,
#   42.1,
#   53.9,
#   56.9,
#   45.1,
#   45.1,
#   38.0,
#   48.6,
#   58.5,
#   67.6,
#   53.0,
#   46.0,
#   56.5,
#   44.1,
#   68.6,
#   41.4,
#   49.8,
#   54.8,
#   35.5,
#   54.2,
#   64.3,
#   37.7,
#   48.4,
#   50.0,
#   36.3,
#   50.1,
#   47.3,
#   50.5,
#   46.9,
#   32.0,
#   44.2,
#   51.4,
#   47.8,
#   49.4,
#   42.1,
#   47.5,
#   47.2,
#   40.9,
#   35.6,
#   60.4,
#   60.4,
#   45.5,
#   53.7,
#   45.9,
#   47.3,
#   45.5,
#   59.4,
#   50.9,
#   46.7,
#   29.1,
#   53.8,
#   45.0,
#   56.8,
#   51.8,
#   64.5,
#   40.1,
#   50.6,
#   48.3,
#   45.1,
#   52.5,
#   38.7,
#   43.1,
#   53.2,
#   42.6,
#   48.3,
#   57.1,
#   36.7,
#   49.9,
#   55.4,
#   49.6,
#   59.8,
#   45.8,
#   46.5,
#   66.1,
#   45.4,
#   42.2,
#   49.5,
#   46.1,
#   48.6,
#   49.0,
#   59.4,
#   40.5,
#   56.4,
#   40.7,
#   37.7,
#   43.6,
#   45.5,
#   39.9],
#  [26.9,
#   31.3,
#   30.9,
#   28.5,
#   31.0,
#   32.8,
#   31.5,
#   35.1,
#   36.0,
#   35.1,
#   34.1,
#   32.6,
#   36.3,
#   31.9,
#   33.1,
#   29.3,
#   26.1,
#   42.8,
#   29.6,
#   32.1,
#   25.0,
#   37.1,
#   32.6,
#   37.4,
#   31.9,
#   32.2,
#   30.5,
#   30.9,
#   35.2,
#   28.0,
#   32.5,
#   37.9,
#   29.7,
#   32.8,
#   34.4,
#   31.2,
#   32.7,
#   35.1,
#   34.7,
#   31.5,
#   33.1,
#   34.8,
#   27.3,
#   32.6,
#   32.4,
#   27.4,
#   31.3,
#   31.1,
#   35.4,
#   37.0,
#   32.2,
#   35.6,
#   33.0,
#   32.3,
#   27.3,
#   34.0,
#   26.1,
#   40.1,
#   35.0,
#   30.5,
#   30.7,
#   31.1,
#   33.5,
#   33.7,
#   35.1,
#   30.3,
#   33.0,
#   32.2,
#   30.8,
#   36.3,
#   32.3,
#   33.1,
#   32.5,
#   29.3,
#   29.7,
#   31.3,
#   31.4,
#   32.9,
#   32.5,
#   35.2,
#   40.3,
#   30.7,
#   35.6,
#   33.7,
#   31.9,
#   31.9,
#   29.3,
#   39.4,
#   30.7,
#   30.1,
#   32.8,
#   31.7,
#   34.6,
#   28.5,
#   33.7,
#   30.1,
#   35.9,
#   33.9,
#   36.6,
#   35.9,
#   33.1,
#   30.7,
#   35.2,
#   31.4,
#   34.5,
#   33.2,
#   30.0,
#   33.7,
#   36.2,
#   39.0,
#   31.1,
#   34.1,
#   39.0,
#   29.0,
#   32.2,
#   31.6,
#   31.7,
#   34.8,
#   30.5,
#   31.3,
#   29.5,
#   26.6,
#   31.7,
#   31.9,
#   31.0,
#   33.1,
#   30.6,
#   40.1,
#   32.4,
#   33.2,
#   30.1,
#   31.8,
#   30.3,
#   35.0,
#   36.8,
#   29.2,
#   37.3,
#   28.7,
#   32.5,
#   29.6,
#   32.6,
#   32.2,
#   36.9,
#   35.2,
#   28.1,
#   36.0,
#   29.5,
#   36.5,
#   30.3,
#   30.7,
#   34.0,
#   32.3,
#   31.5,
#   33.4,
#   30.5,
#   29.3,
#   37.4,
#   34.6,
#   38.3,
#   32.3,
#   32.2,
#   32.6,
#   34.9,
#   32.0,
#   34.3,
#   30.8,
#   29.4,
#   29.0,
#   31.0,
#   33.8],
#  [40.0,
#   42.0,
#   42.9,
#   30.2,
#   40.0,
#   36.6,
#   36.7,
#   42.5,
#   40.8,
#   38.3,
#   40.1,
#   43.8,
#   48.0,
#   37.6,
#   34.1,
#   38.6,
#   37.1,
#   39.3,
#   42.0,
#   30.7,
#   41.0,
#   42.6,
#   42.9,
#   43.9,
#   34.3,
#   41.0,
#   42.2,
#   36.7,
#   33.6,
#   41.6,
#   39.1,
#   40.7,
#   43.2,
#   34.8,
#   40.6,
#   39.1,
#   42.7,
#   49.8,
#   41.8,
#   36.2,
#   41.0,
#   34.5,
#   39.4,
#   40.0,
#   45.0,
#   38.0,
#   40.0,
#   40.9,
#   40.0,
#   34.9,
#   37.2,
#   38.3,
#   39.0,
#   31.8,
#   35.5,
#   35.2,
#   40.2,
#   35.3,
#   36.0,
#   30.8,
#   37.3,
#   34.8,
#   30.9,
#   43.0,
#   34.9,
#   38.1,
#   38.7,
#   34.3,
#   37.9,
#   43.0,
#   39.4,
#   36.1,
#   37.4,
#   39.3,
#   34.5,
#   34.7,
#   44.8,
#   39.7,
#   40.0,
#   46.2,
#   41.9,
#   42.9,
#   32.5,
#   43.1,
#   39.9,
#   34.3,
#   39.8,
#   39.8,
#   41.8,
#   43.6,
#   34.4,
#   40.7,
#   37.4,
#   39.8,
#   39.9,
#   30.1,
#   41.6,
#   39.1,
#   46.2,
#   38.3,
#   33.2,
#   42.1,
#   34.3,
#   37.0,
#   34.4,
#   42.7,
#   37.7,
#   47.1,
#   38.2,
#   36.8,
#   33.1,
#   38.8,
#   46.5,
#   38.5,
#   41.2,
#   32.7,
#   30.3,
#   37.5,
#   39.1,
#   41.3,
#   33.9,
#   31.1,
#   38.3,
#   35.7,
#   36.2,
#   41.0,
#   34.6,
#   33.5,
#   40.3,
#   42.2,
#   48.5,
#   41.4,
#   41.9,
#   45.5,
#   33.2,
#   41.4,
#   40.7,
#   33.9,
#   37.1,
#   41.4,
#   36.7,
#   38.5,
#   41.2,
#   35.5,
#   34.0,
#   36.8,
#   44.0,
#   45.7,
#   33.6,
#   40.5,
#   45.1,
#   39.3,
#   40.1,
#   40.8,
#   49.7,
#   39.6,
#   46.9,
#   38.1,
#   37.7,
#   42.8,
#   34.9,
#   31.2,
#   53.0,
#   34.0,
#   43.2,
#   35.6,
#   35.2,
#   39.3,
#   35.0,
#   33.6,
#   36.5,
#   37.9,
#   49.7,
#   30.1,
#   39.4,
#   42.4,
#   39.3,
#   34.2,
#   38.3,
#   43.5,
#   38.3,
#   39.5,
#   37.7,
#   36.2,
#   32.9,
#   45.3,
#   35.3,
#   39.1,
#   49.5,
#   39.5,
#   40.8,
#   34.1,
#   37.8,
#   32.1,
#   42.8,
#   39.5,
#   36.6,
#   39.5,
#   41.1,
#   44.2,
#   47.0,
#   33.6,
#   40.6,
#   40.8,
#   36.6,
#   42.8,
#   50.5,
#   36.8,
#   37.2,
#   35.6,
#   40.4,
#   32.5,
#   39.7,
#   41.1,
#   37.7,
#   39.3,
#   40.7,
#   37.3,
#   34.6,
#   36.3,
#   47.7,
#   34.5,
#   36.2,
#   29.0,
#   33.3,
#   44.5,
#   45.4,
#   36.4,
#   33.0,
#   40.2,
#   37.6,
#   38.9,
#   37.1,
#   34.7,
#   38.5,
#   43.6,
#   30.7,
#   35.7,
#   32.9,
#   36.8,
#   38.2,
#   31.0,
#   37.4,
#   39.4,
#   43.1,
#   37.3,
#   35.6,
#   40.9,
#   35.8,
#   35.4,
#   48.5,
#   38.9,
#   37.8,
#   37.5,
#   38.8,
#   37.9,
#   31.8,
#   48.2,
#   41.8,
#   41.6,
#   39.4,
#   39.8,
#   39.7,
#   37.5,
#   35.9],
#  [31.9,
#   41.7,
#   37.7,
#   34.6,
#   44.3,
#   24.6,
#   31.2,
#   31.6,
#   27.4,
#   35.9,
#   34.4,
#   43.1,
#   30.1,
#   37.5,
#   28.9,
#   27.7,
#   47.4,
#   35.5,
#   32.9,
#   37.3,
#   56.7,
#   33.8,
#   35.0,
#   27.4,
#   45.0,
#   28.6,
#   35.4,
#   27.5,
#   37.7,
#   41.8,
#   26.2,
#   23.4,
#   33.8,
#   36.8,
#   32.7,
#   36.4,
#   45.6,
#   45.3,
#   38.8,
#   37.6,
#   36.6,
#   35.9,
#   22.9,
#   40.0,
#   45.7,
#   30.3,
#   34.5,
#   35.8,
#   32.8,
#   45.1,
#   41.8,
#   31.1,
#   35.4,
#   28.4,
#   47.7,
#   31.8,
#   43.9,
#   35.6,
#   34.6,
#   36.7,
#   46.6,
#   35.7,
#   32.9,
#   29.3,
#   40.0,
#   40.3,
#   38.9,
#   26.2,
#   25.5,
#   43.7,
#   39.2,
#   36.0,
#   32.6,
#   30.7,
#   27.6,
#   26.0,
#   29.9,
#   32.1,
#   46.2,
#   27.6,
#   35.0,
#   48.4,
#   33.2,
#   49.9,
#   36.8,
#   25.3,
#   35.1,
#   27.8,
#   38.1,
#   33.4,
#   47.1,
#   40.2,
#   31.3,
#   27.8,
#   37.8,
#   26.9,
#   28.1,
#   26.9,
#   29.3,
#   24.4,
#   40.8,
#   28.4,
#   38.5,
#   30.3,
#   24.0,
#   36.7,
#   35.2,
#   31.5,
#   27.7,
#   27.2,
#   37.2,
#   45.6,
#   40.0,
#   35.1,
#   30.1,
#   28.8,
#   36.9,
#   29.3,
#   46.3,
#   33.3,
#   35.1,
#   38.3,
#   46.6,
#   35.2,
#   37.0,
#   33.7,
#   39.8,
#   48.6,
#   49.4,
#   33.8,
#   26.1,
#   43.6,
#   39.6,
#   25.7,
#   40.9,
#   34.1,
#   25.9,
#   34.8,
#   30.8,
#   37.4,
#   41.0,
#   32.9,
#   29.4,
#   35.0,
#   31.8,
#   34.7,
#   28.4,
#   31.0,
#   33.8,
#   36.1,
#   31.5,
#   31.6,
#   31.0,
#   44.9,
#   36.9,
#   39.1,
#   35.7,
#   40.8,
#   40.4,
#   36.9,
#   34.8,
#   34.7,
#   43.9,
#   36.5,
#   27.6,
#   30.1,
#   26.0,
#   37.9,
#   36.7,
#   33.7,
#   40.3,
#   32.0,
#   36.6,
#   43.4,
#   42.4,
#   22.8,
#   29.5,
#   32.1,
#   33.1,
#   41.9,
#   41.8,
#   26.5,
#   35.9,
#   28.2,
#   43.9,
#   35.0,
#   46.9,
#   40.5,
#   32.8,
#   29.1,
#   42.0,
#   25.9,
#   39.2,
#   45.5,
#   30.1,
#   36.7,
#   32.8,
#   34.3,
#   29.4,
#   27.0,
#   25.8,
#   33.3,
#   34.0,
#   39.4,
#   34.4,
#   36.9,
#   29.1,
#   30.1,
#   29.5,
#   37.0,
#   23.3,
#   26.9,
#   42.5,
#   38.4,
#   36.8,
#   29.4,
#   40.5,
#   44.7,
#   38.9,
#   30.2,
#   32.5,
#   46.0,
#   50.6,
#   31.3,
#   37.5,
#   51.1,
#   34.9,
#   36.8,
#   35.1,
#   41.4,
#   31.6,
#   28.0,
#   28.7,
#   39.3,
#   51.9,
#   43.6,
#   40.4,
#   45.5,
#   38.1,
#   26.9,
#   36.5,
#   37.6,
#   43.1,
#   31.0,
#   29.4,
#   27.3,
#   43.2,
#   43.9,
#   44.4,
#   41.6,
#   34.2,
#   36.5,
#   40.2,
#   23.7,
#   34.1,
#   28.3,
#   25.3,
#   40.7,
#   31.1,
#   27.5,
#   25.5,
#   35.7,
#   29.7,
#   41.7,
#   29.9,
#   37.5,
#   26.2,
#   33.7,
#   29.8,
#   41.8,
#   37.7,
#   42.0,
#   48.9,
#   33.9,
#   41.4,
#   31.4,
#   36.7,
#   47.8,
#   23.7,
#   35.0,
#   31.9,
#   31.1,
#   24.2,
#   30.2,
#   30.6,
#   31.2,
#   34.9,
#   35.3,
#   35.7,
#   27.5,
#   49.3,
#   34.9,
#   34.2,
#   30.0,
#   24.4,
#   33.3,
#   46.1,
#   30.4,
#   32.6,
#   44.4,
#   29.4,
#   37.3,
#   34.8,
#   37.0,
#   34.2,
#   57.8,
#   24.6,
#   32.4,
#   36.4,
#   31.9,
#   25.0,
#   50.3,
#   27.5,
#   35.3,
#   29.8,
#   28.1,
#   45.6,
#   35.4,
#   30.6,
#   34.5,
#   39.4,
#   30.0,
#   40.0,
#   34.7,
#   36.8,
#   29.1,
#   31.8,
#   32.9,
#   30.0,
#   18.8,
#   34.7,
#   31.5,
#   30.9,
#   43.5,
#   34.0,
#   50.3,
#   26.8,
#   31.9,
#   27.6,
#   34.1,
#   31.1,
#   37.6,
#   42.3,
#   32.5,
#   47.2,
#   34.2,
#   27.8,
#   24.8,
#   29.9,
#   26.5,
#   28.9,
#   35.5,
#   29.6,
#   38.5,
#   31.1,
#   21.6,
#   25.9,
#   47.1,
#   35.2,
#   37.0,
#   32.6,
#   31.1,
#   24.7,
#   38.1,
#   44.8,
#   30.7,
#   31.8,
#   35.7,
#   31.4,
#   31.1,
#   36.4,
#   31.0,
#   43.6,
#   35.7,
#   29.1,
#   33.6,
#   31.7,
#   37.9,
#   37.1,
#   36.1,
#   42.6,
#   26.2,
#   36.9,
#   45.5,
#   41.7,
#   25.5,
#   41.9,
#   36.9,
#   30.7,
#   35.3,
#   29.3,
#   35.5,
#   30.8,
#   40.6,
#   31.3,
#   30.3,
#   37.0,
#   33.8,
#   31.5,
#   35.3,
#   31.6,
#   29.8,
#   31.2,
#   33.7,
#   32.8,
#   40.2,
#   46.6,
#   44.0,
#   37.3,
#   37.2,
#   25.2,
#   40.4,
#   31.0,
#   28.6,
#   33.4,
#   31.5,
#   39.6,
#   38.6,
#   40.2,
#   33.6,
#   30.2,
#   33.9,
#   40.5,
#   43.9,
#   48.3,
#   38.4,
#   38.5,
#   32.8,
#   39.1,
#   31.4,
#   25.5,
#   35.5,
#   26.6,
#   22.9,
#   25.3,
#   45.0,
#   37.3,
#   37.9,
#   29.4,
#   41.0,
#   27.6,
#   27.9,
#   35.6,
#   39.9,
#   36.4,
#   40.9,
#   35.3,
#   38.1,
#   30.1,
#   42.2,
#   42.3,
#   35.6,
#   35.5,
#   42.9,
#   30.1,
#   34.8,
#   54.5,
#   40.1,
#   36.9,
#   36.8,
#   39.8,
#   30.7,
#   26.8,
#   24.9,
#   20.7,
#   42.2,
#   36.0,
#   34.2,
#   33.4,
#   32.9,
#   52.0,
#   34.1,
#   40.7,
#   40.3,
#   33.1,
#   37.8,
#   44.8,
#   26.4,
#   33.7,
#   25.7,
#   29.0,
#   35.9,
#   21.2,
#   43.1,
#   32.6,
#   24.2,
#   40.1,
#   35.0,
#   43.8,
#   37.1,
#   42.3,
#   34.9,
#   39.1,
#   49.3,
#   41.2,
#   31.2,
#   33.4,
#   28.0,
#   33.5,
#   30.4,
#   25.8,
#   26.7,
#   31.8,
#   32.3,
#   33.3,
#   37.5,
#   27.3,
#   29.7,
#   26.7,
#   35.0,
#   33.6,
#   30.9,
#   22.3,
#   34.7,
#   42.1,
#   27.9,
#   38.4,
#   31.2,
#   42.0,
#   37.4,
#   34.4,
#   30.6,
#   37.3,
#   35.1,
#   41.6,
#   38.7,
#   29.5,
#   38.4,
#   33.6,
#   24.0,
#   38.7,
#   40.3,
#   31.3,
#   34.8,
#   36.4,
#   26.7,
#   21.9,
#   27.8,
#   27.1,
#   37.8,
#   39.2,
#   22.3,
#   36.8,
#   31.4,
#   33.6,
#   27.9,
#   29.8,
#   53.3,
#   39.7,
#   39.9,
#   25.1,
#   34.7,
#   30.7,
#   24.3,
#   29.1,
#   30.8,
#   28.8,
#   25.8,
#   20.1,
#   32.6,
#   51.7,
#   18.4,
#   38.9,
#   57.7,
#   38.3,
#   23.7,
#   45.5,
#   41.0,
#   34.6,
#   41.0,
#   39.8,
#   31.2,
#   27.1,
#   35.5,
#   42.3,
#   22.8,
#   27.4,
#   31.2,
#   32.5,
#   34.4,
#   48.5,
#   26.5,
#   31.8,
#   25.7,
#   37.1,
#   35.9,
#   27.2,
#   33.8,
#   32.1,
#   26.0,
#   49.2,
#   44.6,
#   24.2,
#   32.0,
#   43.5,
#   22.6,
#   28.7,
#   36.6,
#   29.4,
#   27.0,
#   48.1,
#   34.6,
#   35.9,
#   42.8,
#   24.7,
#   32.9,
#   47.5,
#   36.9,
#   35.8,
#   32.7,
#   39.6,
#   33.8,
#   33.7,
#   24.3,
#   31.0,
#   21.0,
#   47.5,
#   39.2,
#   40.9,
#   26.4,
#   33.6,
#   36.3,
#   24.2,
#   46.4,
#   40.9,
#   34.7,
#   29.3,
#   35.7,
#   36.1,
#   44.5,
#   43.7,
#   32.3,
#   34.6,
#   22.0,
#   27.9,
#   32.0,
#   44.5,
#   32.5,
#   35.6,
#   36.4,
#   35.7,
#   31.9,
#   48.2,
#   40.8,
#   23.7,
#   34.2,
#   29.4,
#   53.5,
#   31.8,
#   32.7,
#   30.5,
#   31.7,
#   26.3,
#   38.6,
#   29.8,
#   28.5,
#   42.6,
#   34.6,
#   38.5,
#   27.6,
#   30.9,
#   29.5,
#   33.8,
#   38.9,
#   47.3,
#   45.3,
#   36.2,
#   28.6,
#   32.7,
#   35.2,
#   32.9,
#   30.0,
#   38.2,
#   40.2,
#   45.9,
#   37.8,
#   40.7,
#   26.2,
#   43.2,
#   29.4,
#   38.1,
#   42.5,
#   33.7,
#   38.2,
#   29.7,
#   38.2,
#   23.3,
#   34.5,
#   31.2,
#   22.7,
#   28.3,
#   29.9,
#   42.3,
#   37.0,
#   40.4,
#   22.5,
#   32.1,
#   31.8,
#   24.6,
#   43.0,
#   43.4,
#   36.3,
#   35.4,
#   46.3,
#   38.7,
#   26.2,
#   30.3,
#   42.2,
#   40.8,
#   34.1,
#   31.7,
#   36.4,
#   40.1,
#   45.9,
#   31.1,
#   25.1,
#   37.7,
#   28.6,
#   27.7,
#   32.3,
#   37.1,
#   30.2,
#   43.9,
#   31.0,
#   37.8,
#   44.2,
#   34.4,
#   37.3,
#   29.8,
#   45.8,
#   28.9,
#   31.7,
#   41.7,
#   37.0,
#   37.4,
#   34.6,
#   40.9,
#   43.6,
#   28.4,
#   46.3,
#   26.8,
#   30.8,
#   41.1,
#   26.7,
#   24.0,
#   30.5,
#   42.3,
#   34.0,
#   33.7,
#   46.8,
#   32.8,
#   30.1,
#   29.7,
#   28.8,
#   38.7,
#   38.1,
#   42.0,
#   41.9,
#   31.3,
#   33.8,
#   33.6,
#   31.3,
#   40.6,
#   35.9,
#   29.4,
#   34.3,
#   30.5,
#   29.7,
#   34.4,
#   25.8,
#   44.8,
#   20.6,
#   40.1,
#   33.4,
#   33.1,
#   31.2,
#   40.1,
#   47.3]]

# %%
#required to run battle sim/ monte carlo
resultsframe = pd.DataFrame(index=pk.Pokemon_df.index, columns=pk.Pokemon_df.index)
resultsframe.fillna(value=0, inplace=True)
# Out:
# C:\Users\Hayden\AppData\Local\Temp\ipykernel_29560\458017336.py:3: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   resultsframe.fillna(value=0, inplace=True)

# %%
pokemon_list = list(pokemon_dict)

# %%
def battlesim(timesdict,healthleft,heals=False,starthealth=1):
    '''Pits every pokemon against each other'''
    for i in range(len(pokemon_list)):
        for j in range(i,len(pokemon_list)):
            Pokemon = pokemon_list[i]
            other = pokemon_list[j]
            if i == j:
                timesdict[(Pokemon,other)].append(0)
                healthleft[(Pokemon,other)].append(1)
                victor = ""
                continue
            else:
                victor,nturns,P_hp,o_hp = pk.runbattle(pokemon_dict[Pokemon],pokemon_dict[other],healing=heals,remaininghealth=starthealth)
            timesdict[(Pokemon,other)].append(nturns)
            healthleft[(Pokemon,other)].append(P_hp)
            if Pokemon != other:
                timesdict[other,Pokemon].append(nturns)
                healthleft[(other,Pokemon)].append(o_hp)
            if victor == pokemon_dict[Pokemon].name:
                resultsframe.loc[other,Pokemon]=0
                resultsframe.loc[Pokemon,other]=1
            elif victor == pokemon_dict[other].name:
                resultsframe.loc[Pokemon,other]=0
                resultsframe.loc[other,Pokemon]=1
            else:
                resultsframe.loc[Pokemon,other]=0
                resultsframe.loc[other,Pokemon]=0
    return resultsframe

# %%
pokemon_dict['mewtwo'].level
# Out:
# 50.0

# %%
def battlesim_simple(pokemon_list):
    '''Pits every pokemon against each other'''
    for i in range(len(pokemon_list)):
        for j in range(i,len(pokemon_list)):
            Pokemon = pokemon_list[i]
            other = pokemon_list[j]
            if i == j:
                resultsframe.loc[other,Pokemon]=0
                resultsframe.loc[Pokemon,other]=0
                continue
            else:
                victor,nturns,P_hp,o_hp = pk.runbattle(pokemon_dict[Pokemon],pokemon_dict[other])
            if victor == pokemon_dict[Pokemon].name:
                resultsframe.loc[other,Pokemon]=0
                resultsframe.loc[Pokemon,other]=1
            elif victor == pokemon_dict[other].name:
                resultsframe.loc[Pokemon,other]=0
                resultsframe.loc[other,Pokemon]=1
            else:
                resultsframe.loc[Pokemon,other]=0
                resultsframe.loc[other,Pokemon]=0
    return resultsframe

def montepython_simple(n,pokemon_list):
    '''Runs battlesim() n times and adds it to one dataframe. Returns final dataframe.'''
    monte_frame = pd.DataFrame(index=pk.Pokemon_df.index, columns=pk.Pokemon_df.index)
    monte_frame.fillna(value=0, inplace=True)
    for run in range(n):
        monte_frame = monte_frame + battlesim_simple(pokemon_list)
        
    return monte_frame

# %%
n = 1000
resultsframe = montepython_simple(n,pokemon_list)
resultsframe
# Out:
# C:\Users\Hayden\AppData\Local\Temp\ipykernel_29560\2817143977.py:27: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   monte_frame.fillna(value=0, inplace=True)
# name        bulbasaur  ivysaur  venusaur  charmander  charmeleon  charizard  \
# name
# bulbasaur           0      469       304         839         648        593
# ivysaur           531        0       251         879         685        617
# venusaur          696      749         0         971         884        813
# charmander        148      109        26           0         121         22
# charmeleon        339      296       105         877           0        135
# ...               ...      ...       ...         ...         ...        ...
# dratini           454      359       183         441         189         68
# dragonair         557      617       318         725         367        122
# dragonite         617      675       493         921         785        475
# mewtwo            987      992       987        1000         992        951
# mew               869      838       768         915         888        709
#
# name        squirtle  wartortle  blastoise  caterpie  ...  aerodactyl  \
# name                                                  ...
# bulbasaur        133         32         18       995  ...         307
# ivysaur          120         56         22       999  ...         287
# venusaur         255         96         38      1000  ...         495
# charmander       695        432        158       984  ...         122
# charmeleon       883        714        467       997  ...         313
# ...              ...        ...        ...       ...  ...         ...
# dratini          420         94         25       999  ...          31
# dragonair        606        329         66      1000  ...         114
# dragonite        933        741        617      1000  ...         478
# mewtwo           999        995        981      1000  ...         940
# mew              943        899        771       967  ...         667
#
# name        snorlax  articuno  zapdos  moltres  dratini  dragonair  dragonite  \
# name
# bulbasaur        14       206      22      696      530        421        362
# ivysaur          29       208      14      727      611        358        297
# venusaur         30       310       9      880      795        655        472
# charmander        0         0       0        0      544        259         71
# charmeleon        4         0       2        1      807        617        203
# ...             ...       ...     ...      ...      ...        ...        ...
# dratini           0         0       0        7        0        342        131
# dragonair        27         0       0       21      644          0        177
# dragonite       197        42      77      301      860        816          0
# mewtwo          428       549     767      978      996        999        969
# mew             339       431     414      725      888        850        712
#
# name        mewtwo  mew
# name
# bulbasaur       12  127
# ivysaur          6  151
# venusaur         7  218
# charmander       0   71
# charmeleon       6  104
# ...            ...  ...
# dratini          1   99
# dragonair        1  133
# dragonite       28  261
# mewtwo           0  679
# mew            306    0
#
# [151 rows x 151 columns]

# %%
resultsframe.to_csv('Level_50_1000runs.csv')

# %%
#Initialize timedict and health left for a run of battlesim
timesdict = {}
healthleft = {}
for i in range(len(pokemon_list)):
    for j in range(len(pokemon_list)):
        timesdict[(pokemon_list[i],pokemon_list[j])] = []
        healthleft[(pokemon_list[i],pokemon_list[j])] = []

battlesim(timesdict,healthleft)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 9
#       6         timesdict[(pokemon_list[i],pokemon_list[j])] = []
#       7         healthleft[(pokemon_list[i],pokemon_list[j])] = []
# ----> 9 battlesim_simple()
#
# TypeError: battlesim_simple() missing 1 required positional argument: 'pokemon_list'

# %%
def montepython(n,heals = False,starthealth=1.0):
    time_dict = {}
    health_left = {}
    for i in range(len(pokemon_list)):
        for j in range(len(pokemon_list)):
            time_dict[(pokemon_list[i],pokemon_list[j])] = []
            health_left[(pokemon_list[i],pokemon_list[j])] = []
    '''Runs battlesim() n times and adds it to one dataframe. Returns final dataframe.'''
    monte_frame = pd.DataFrame(index=pk.Pokemon_df.index, columns=pk.Pokemon_df.index)
    monte_frame.fillna(value=0, inplace=True)
    for run in range(n):
        monte_frame = monte_frame + battlesim(time_dict,health_left,heals,starthealth)
        
    return monte_frame,time_dict,health_left

# %%
def writetocsv(filename,dict_name):
    with open(filename,'w') as file:
        writer = csv.writer(file)
        writer.writerow(dict_name.keys())
        writer.writerows(zip(*dict_name.values()))

# %%
healthpercents = [1,.75,.5,.25]
number_of_runs = 100
for perc in healthpercents:
    totalresultsframe,time_dict,health_left=montepython(number_of_runs,heals=True,starthealth=perc)
    stringhp = "%druns%dhp_heals" % (number_of_runs,perc*100)
    totalresultsframe.to_csv(stringhp+'_wins.csv')
    writetocsv(stringhp+'_times.csv',time_dict)
    writetocsv(stringhp+'_health.csv',health_left)

# %%
## Uncomment below and change how many runs of the monte carlo simulation you would like.
number_of_runs = 3
totalresultsframe,time_dict,health_left=montepython(number_of_runs)
totalresultsframe
#totalresultsframe.to_csv('10runs.csv')




# with open('test.csv','w') as testfile:
#     writer = csv.writer(testfile)
#     #writer = csv.DictWriter(testfile,fieldnames = key_list)
#     writer.writerow(time_dict.keys())
#     writer.writerows(zip(*time_dict.values()))
# Out:
# C:\Users\Hayden\AppData\Local\Temp\ipykernel_29560\2430976025.py:10: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   monte_frame.fillna(value=0, inplace=True)
# "\nwith open('test.csv','w') as testfile:\n    writer = csv.writer(testfile)\n    #writer = csv.DictWriter(testfile,fieldnames = key_list)\n    writer.writerow(time_dict.keys())\n    writer.writerows(zip(*time_dict.values()))\n    "

# %%
totalresultsframe
# Out:
# name        bulbasaur  ivysaur  venusaur  charmander  charmeleon  charizard  \
# name
# bulbasaur           1        2         1           3           2          1
# ivysaur             1        1         0           3           3          0
# venusaur            2        3         0           3           3          2
# charmander          0        0         0           1           0          0
# charmeleon          1        0         0           3           0          2
# ...               ...      ...       ...         ...         ...        ...
# dratini             1        1         1           1           0          1
# dragonair           1        2         2           3           2          0
# dragonite           2        2         0           2           2          3
# mewtwo              3        3         3           3           3          3
# mew                 2        3         3           3           3          3
#
# name        squirtle  wartortle  blastoise  caterpie  ...  aerodactyl  \
# name                                                  ...
# bulbasaur          0          0          0         3  ...           1
# ivysaur            0          0          0         3  ...           0
# venusaur           0          0          0         3  ...           1
# charmander         2          3          1         3  ...           0
# charmeleon         3          3          2         3  ...           1
# ...              ...        ...        ...       ...  ...         ...
# dratini            2          0          0         3  ...           0
# dragonair          1          0          0         3  ...           0
# dragonite          3          2          3         3  ...           3
# mewtwo             3          3          3         3  ...           3
# mew                3          3          2         3  ...           2
#
# name        snorlax  articuno  zapdos  moltres  dratini  dragonair  dragonite  \
# name
# bulbasaur         0         0       0        1        2          2          1
# ivysaur           0         1       0        1        2          1          1
# venusaur          0         2       0        3        2          1          2
# charmander        0         0       0        0        2          0          1
# charmeleon        1         0       0        0        3          1          1
# ...             ...       ...     ...      ...      ...        ...        ...
# dratini           0         0       0        0        2          0          1
# dragonair         0         0       0        0        2          1          0
# dragonite         0         0       0        2        2          3          0
# mewtwo            0         1       2        3        3          3          3
# mew               1         3       1        2        2          2          3
#
# name        mewtwo  mew
# name
# bulbasaur        0    1
# ivysaur          0    0
# venusaur         0    0
# charmander       0    0
# charmeleon       0    0
# ...            ...  ...
# dratini          0    1
# dragonair        0    1
# dragonite        0    0
# mewtwo           2    2
# mew              1    1
#
# [151 rows x 151 columns]

# %%
totalresultsframe.loc['squirtle'] #squirtle's win numbers
# Out:
# name
# bulbasaur      4
# ivysaur        4
# venusaur       3
# charmander    10
# charmeleon     7
#               ..
# dratini        4
# dragonair      4
# dragonite      0
# mewtwo         0
# mew            3
# Name: squirtle, Length: 151, dtype: int64

# %%
health_left[('squirtle','mew')] #squirtle's health left when battling against mew
#(lol get rekt)
# Out:
# [0.0, 0.0, 0.0, 0.311, 0.0, 0.0, 0.118, 0.0, 0.214, 0.0]

# %%
time_dict[('squirtle','mew')] #amount of turns
# Out:
# {5: 2, 19: 1, 7: 2, 3: 1, 13: 1, 21: 1, 17: 1, 11: 1}

# %% [markdown]
# ## Everything up until this point is needed to produce your own 1000runs.csv.
#
# After this breakpoint is the code that we used to explore the data.

# %%
# Here we provide you our 1000runs.csv that was the product of the cell above.
totalresultsframe = pd.read_csv('1000runs.csv', index_col='name')
totalresultsframe
# Out:
#             bulbasaur  ivysaur  venusaur  charmander  charmeleon  charizard  \
# name
# bulbasaur           0      467        11         583           0          0
# ivysaur           533        0         5        1000         335        174
# venusaur          989      965         0        1000         712        597
# charmander        417        0         0           0           0          0
# charmeleon       1000      624       275        1000           0          0
# ...               ...      ...       ...         ...         ...        ...
# dratini           903        1         0         911          47          0
# dragonair         997        1         0         999         305         27
# dragonite        1000        1         0        1000         375        241
# mewtwo           1000      958       430        1000         965        707
# mew              1000      999        44        1000         889        709
#
#             squirtle  wartortle  blastoise  caterpie  ...  aerodactyl  \
# name                                                  ...
# bulbasaur          2          0          0       363  ...           0
# ivysaur          910        957        672      1000  ...          62
# venusaur        1000       1000       1000      1000  ...         870
# charmander         0          0          0       368  ...           0
# charmeleon       520        209          4      1000  ...         338
# ...              ...        ...        ...       ...  ...         ...
# dratini           13          2          0       943  ...           0
# dragonair        378        108          0      1000  ...           0
# dragonite        914        685         14      1000  ...           0
# mewtwo          1000       1000        898      1000  ...         892
# mew             1000       1000       1000      1000  ...         925
#
#             snorlax  articuno  zapdos  moltres  dratini  dragonair  dragonite  \
# name
# bulbasaur         0         0       0        0       97          3          0
# ivysaur          91         0       0        0      999        999        999
# venusaur        126         0     136      188     1000       1000       1000
# charmander        0         0       0        0       89          1          0
# charmeleon        1        96       0        0      951        689        616
# ...             ...       ...     ...      ...      ...        ...        ...
# dratini           0         0       0        0        0         40          1
# dragonair         0         0       0        0      960          0         43
# dragonite         0         0       0       35      999        937          0
# mewtwo            0       114     310      978     1000       1000        999
# mew               0        41      60     1000     1000       1000       1000
#
#             mewtwo  mew
# name
# bulbasaur        0    0
# ivysaur         29    0
# venusaur       496  945
# charmander       0    0
# charmeleon      29   91
# ...            ...  ...
# dratini          0    0
# dragonair        0    0
# dragonite        1    0
# mewtwo           0  332
# mew            648    0
#
# [151 rows x 151 columns]
